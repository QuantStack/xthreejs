// %% [markdown]
// # Textures

// %%
#include <xthreejs/xthreejs.hpp>

// %%
auto checker_tex = xthree::image_texture_generator()
    .imageUri("img/checkerboard.png")
    .finalize();

// %%
checker_tex
// Out:
// A Jupyter widget

// %%
auto earth_tex = xthree::image_texture_generator()
    .imageUri("img/earth.jpg")
    .finalize();

// %%
earth_tex
// Out:
// A Jupyter widget
